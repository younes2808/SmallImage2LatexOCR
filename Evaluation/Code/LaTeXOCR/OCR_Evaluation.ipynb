# %%
# Clone the GitHub repository(Evaluation DATASET)
# !git clone https://github.com/younes2808/SmallImage2LatexOCR.git
# Out:
# Cloning into 'SmallImage2LatexOCR'...
# remote: Enumerating objects: 427, done.
# remote: Counting objects: 100% (427/427), done.
# remote: Compressing objects: 100% (420/420), done.
# remote: Total 427 (delta 2), reused 415 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (427/427), 528.33 KiB | 1.81 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
#Installing pix2tex(LatexOCR can be found inside)
# !pip install "pix2tex[gui]"
# Out:
# Collecting pix2tex[gui]
#   Downloading pix2tex-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (4.67.1)
# Collecting munch>=2.5.0 (from pix2tex[gui])
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (2.5.1+cu121)
# Requirement already satisfied: opencv-python-headless>=4.1.1.26 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (4.11.0.86)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (2.32.3)
# Requirement already satisfied: einops>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (0.8.0)
# Collecting x-transformers==0.15.0 (from pix2tex[gui])
#   Downloading x_transformers-0.15.0-py3-none-any.whl.metadata (651 bytes)
# Requirement already satisfied: transformers>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (4.47.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (0.21.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (1.26.4)
# Requirement already satisfied: Pillow>=9.1.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (11.1.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (6.0.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (2.2.2)
# Collecting timm==0.5.4 (from pix2tex[gui])
#   Downloading timm-0.5.4-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: albumentations<=1.4.24,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from pix2tex[gui]) (1.4.20)
# Collecting PyQt6 (from pix2tex[gui])
#   Downloading PyQt6-6.8.0-cp39-abi3-manylinux_2_35_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt6-WebEngine (from pix2tex[gui])
#   Downloading PyQt6_WebEngine-6.8.0-cp39-abi3-manylinux_2_35_x86_64.whl.metadata (1.8 kB)
# Collecting pyside6 (from pix2tex[gui])
#   Downloading PySide6-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting pynput (from pix2tex[gui])
#   Downloading pynput-1.7.7-py2.py3-none-any.whl.metadata (31 kB)
# Collecting screeninfo (from pix2tex[gui])
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting latex2sympy2 (from pix2tex[gui])
#   Downloading latex2sympy2-1.9.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm==0.5.4->pix2tex[gui]) (0.20.1+cu121)
# Collecting entmax (from x-transformers==0.15.0->pix2tex[gui])
#   Downloading entmax-1.3-py3-none-any.whl.metadata (348 bytes)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (1.13.1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (2.10.5)
# Requirement already satisfied: albucore==0.0.19 in /usr/local/lib/python3.11/dist-packages (from albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (0.0.19)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.11/dist-packages (from albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (0.2.2)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.19->albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (3.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->pix2tex[gui]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->pix2tex[gui]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->pix2tex[gui]) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pix2tex[gui]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pix2tex[gui]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pix2tex[gui]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pix2tex[gui]) (2024.12.14)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.0->pix2tex[gui]) (0.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->pix2tex[gui]) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.1->pix2tex[gui]) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.1->pix2tex[gui]) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.18.0->pix2tex[gui]) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.18.0->pix2tex[gui]) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.18.0->pix2tex[gui]) (0.5.2)
# Collecting antlr4-python3-runtime==4.7.2 (from latex2sympy2->pix2tex[gui])
#   Downloading antlr4-python3-runtime-4.7.2.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pynput->pix2tex[gui]) (1.17.0)
# Collecting evdev>=1.3 (from pynput->pix2tex[gui])
#   Downloading evdev-1.8.0.tar.gz (32 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-xlib>=0.17 (from pynput->pix2tex[gui])
#   Downloading python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting PyQt6-sip<14,>=13.8 (from PyQt6->pix2tex[gui])
#   Downloading PyQt6_sip-13.9.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (420 bytes)
# Collecting PyQt6-Qt6<6.9.0,>=6.8.0 (from PyQt6->pix2tex[gui])
#   Downloading PyQt6_Qt6-6.8.1-py3-none-manylinux_2_35_x86_64.whl.metadata (534 bytes)
# Collecting PyQt6-WebEngine-Qt6<6.9.0,>=6.8.0 (from PyQt6-WebEngine->pix2tex[gui])
#   Downloading PyQt6_WebEngine_Qt6-6.8.1-py3-none-manylinux_2_35_x86_64.whl.metadata (574 bytes)
# Collecting shiboken6==6.8.1.1 (from pyside6->pix2tex[gui])
#   Downloading shiboken6-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Collecting PySide6-Essentials==6.8.1.1 (from pyside6->pix2tex[gui])
#   Downloading PySide6_Essentials-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting PySide6-Addons==6.8.1.1 (from pyside6->pix2tex[gui])
#   Downloading PySide6_Addons-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations<=1.4.24,>=0.5.2->pix2tex[gui]) (2.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.7.1->pix2tex[gui]) (3.0.2)
# Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 21.0 MB/s eta 0:00:00
# Downloading x_transformers-0.15.0-py3-none-any.whl (11 kB)
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Downloading latex2sympy2-1.9.1-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.8/89.8 kB 7.1 MB/s eta 0:00:00
# Downloading pix2tex-0.1.4-py3-none-any.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.0/427.0 kB 29.3 MB/s eta 0:00:00
# Downloading pynput-1.7.7-py2.py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 8.4 MB/s eta 0:00:00
# Downloading PyQt6-6.8.0-cp39-abi3-manylinux_2_35_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 43.0 MB/s eta 0:00:00
# Downloading PyQt6_WebEngine-6.8.0-cp39-abi3-manylinux_2_35_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.3/297.3 kB 22.2 MB/s eta 0:00:00
# Downloading PySide6-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl (532 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.7/532.7 kB 31.5 MB/s eta 0:00:00
# Downloading PySide6_Addons-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl (160.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 MB 6.8 MB/s eta 0:00:00
# Downloading PySide6_Essentials-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl (95.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 MB 7.2 MB/s eta 0:00:00
# Downloading shiboken6-6.8.1.1-cp39-abi3-manylinux_2_28_x86_64.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 10.2 MB/s eta 0:00:00
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading PyQt6_Qt6-6.8.1-py3-none-manylinux_2_35_x86_64.whl (72.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.6/72.6 MB 8.1 MB/s eta 0:00:00
# Downloading PyQt6_sip-13.9.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 14.7 MB/s eta 0:00:00
# Downloading PyQt6_WebEngine_Qt6-6.8.1-py3-none-manylinux_2_35_x86_64.whl (105.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.2/105.2 MB 8.3 MB/s eta 0:00:00
# Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 13.0 MB/s eta 0:00:00
# Downloading entmax-1.3-py3-none-any.whl (13 kB)
# Building wheels for collected packages: antlr4-python3-runtime, evdev
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.7.2-py3-none-any.whl size=140931 sha256=afe6ff32d7dbe9b029eab7fa168b0b8ed230c0fef6e3d6672a2993480e192481
#   Stored in directory: /root/.cache/pip/wheels/c4/f4/c7/71f768e561b9cc8bce3160d1229728d0d77fd5fd6d4f5d960b
#   Building wheel for evdev (pyproject.toml) ... done
#   Created wheel for evdev: filename=evdev-1.8.0-cp311-cp311-linux_x86_64.whl size=112417 sha256=52d810998e8dc3dd2b5d9997597e5a364bfc948fef8d7a4ca914427c31fbba3b
#   Stored in directory: /root/.cache/pip/wheels/f7/fb/53/994d96d15ab85b1a9ae68af697b29f6bba8e7a8d9d43762f6a
# Successfully built antlr4-python3-runtime evdev
# Installing collected packages: PyQt6-WebEngine-Qt6, PyQt6-Qt6, antlr4-python3-runtime, shiboken6, screeninfo, python-xlib, PyQt6-sip, munch, evdev, PySide6-Essentials, PyQt6, pynput, latex2sympy2, PySide6-Addons, PyQt6-WebEngine, pyside6, entmax, x-transformers, timm, pix2tex
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.14
#     Uninstalling timm-1.0.14:
#       Successfully uninstalled timm-1.0.14
# Successfully installed PyQt6-6.8.0 PyQt6-Qt6-6.8.1 PyQt6-WebEngine-6.8.0 PyQt6-WebEngine-Qt6-6.8.1 PyQt6-sip-13.9.1 PySide6-Addons-6.8.1.1 PySide6-Essentials-6.8.1.1 antlr4-python3-runtime-4.7.2 entmax-1.3 evdev-1.8.0 latex2sympy2-1.9.1 munch-4.0.0 pix2tex-0.1.4 pynput-1.7.7 pyside6-6.8.1.1 python-xlib-0.33 screeninfo-0.8.1 shiboken6-6.8.1.1 timm-0.5.4 x-transformers-0.15.0

# %%
import difflib
import os
from PIL import Image
from pix2tex.cli import LatexOCR
import time

def normalize_latex(latex_string):
    """
    Normalize the LaTeX string by removing unnecessary spaces and ensuring consistent formatting.
    """
    latex_string = latex_string.replace(" ", "").replace("\\,", "").replace("\\ ", "")
    latex_string = latex_string.replace("...", "\\dots")  # Normalize ellipsis
    return latex_string

def compare_latex(correct_latex, ocr_latex):
    """
    Compare the correctness of the OCR output with the correct LaTeX expression.
    """
    # Normalize both strings
    normalized_correct = normalize_latex(correct_latex)
    normalized_ocr = normalize_latex(ocr_latex)

    # Use difflib to compare the two strings
    diff = difflib.ndiff(normalized_correct, normalized_ocr)
    similarity = sum(1 for c in diff if c[0] == ' ') / len(normalized_correct)

    return similarity

def run_ocr_and_compare(img_path, txt_path, ocr_model):
    """
    Run OCR on the image and compare the result with the corresponding LaTeX in the text file.
    """
    # Start timer to measure OCR processing time
    start_time = time.time()

    # Open the image
    img = Image.open(img_path)

    # Run OCR to get LaTeX output
    ocr_latex = ocr_model(img)

    # End timer to calculate elapsed time
    elapsed_time = time.time() - start_time

    # Read the correct LaTeX from the corresponding .txt file
    with open(txt_path, "r") as file:
        correct_latex = file.read().strip()

    # Compare the LaTeX strings
    similarity_score = compare_latex(correct_latex, ocr_latex)

    return similarity_score, ocr_latex, correct_latex, elapsed_time

def process_dataset(dataset_dir, ocr_model, output_file):
    """
    Process the entire dataset, comparing OCR results with ground truth LaTeX and logging results.
    """
    passed_count = 0
    total_time = 0
    total_comparisons = 0
    total_similarity = 0

    # Open the output file to write results
    with open(output_file, 'w') as f:
        # Loop through all folders from 000 to 100
        for i in range(101):  # 0 to 100
            folder_name = f"{str(i).zfill(3)}"  # Format as 000, 001, ..., 100
            folder_path = os.path.join(dataset_dir, folder_name)

            if os.path.isdir(folder_path):  # Process only directories
                f.write(f"Processing folder: {folder_name}\n")
                # Loop through all image files from 000.png to 100.png
                for j in range(101):  # 0 to 100
                    img_name = f"{str(j).zfill(3)}.png"
                    txt_name = f"{str(j).zfill(3)}.txt"

                    img_path = os.path.join(folder_path, img_name)
                    txt_path = os.path.join(folder_path, txt_name)

                    if os.path.exists(img_path) and os.path.exists(txt_path):
                        similarity_score, ocr_latex, correct_latex, elapsed_time = run_ocr_and_compare(img_path, txt_path, ocr_model)

                        f.write(f"Folder {folder_name}, Image {img_name}: Similarity = {similarity_score:.4f}\n")
                        f.write(f"OCR LaTeX: {ocr_latex}\n")
                        f.write(f"Correct LaTeX: {correct_latex}\n")
                        f.write(f"Time taken for OCR: {elapsed_time:.4f} seconds\n")

                        # Provide feedback based on similarity score
                        if similarity_score > 0.95:
                            f.write("OCR output is highly accurate.\n")
                        elif similarity_score > 0.85:
                            f.write("OCR output is fairly accurate.\n")
                        else:
                            f.write("OCR output has significant differences.\n")

                        f.write("-" * 50 + "\n")

                        # Count the number of "passed" results (similarity > 0.9)
                        if similarity_score > 0.9:
                            passed_count += 1

                        # Accumulate total time for calculating average and similarity score
                        total_time += elapsed_time
                        total_comparisons += 1
                        total_similarity += similarity_score


        # After processing all files, write the summary to the output file
        if total_comparisons > 0:
            avg_time = total_time / total_comparisons
        else:
            avg_time = 0

        # Calculating average similarity score
        avg_sim_score = total_similarity / total_comparisons

        #Writing summary
        f.write("\nSummary:\n")
        f.write(f"Total number of comparisons: {total_comparisons}\n")
        f.write(f"Number of passed comparisons(similarity > 0.9): {passed_count}\n")
        f.write(f"Percentage of passed comparisons: {passed_count/total_comparisons}\n")
        f.write(f"Average similarity score: {avg_sim_score}\n")
        f.write(f"Average OCR response time: {avg_time:.4f} seconds\n")

# Initialize the OCR model
model = LatexOCR()

# Define the root directory where your dataset is stored
dataset_dir = "/content/SmallImage2LatexOCR/Dataset"  # Change this path as needed

# Define the output file
output_file = "LaTeXOCR.txt"

# Process the entire dataset and write results to the output file
process_dataset(dataset_dir, model, output_file)
# Out:
# /usr/local/lib/python3.11/dist-packages/pix2tex/cli.py:84: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(self.args.checkpoint, map_location=self.args.device))
# /usr/local/lib/python3.11/dist-packages/pix2tex/cli.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.image_resizer.load_state_dict(torch.load(os.path.join(os.path.dirname(self.args.checkpoint), 'image_resizer.pth'), map_location=self.args.device))
